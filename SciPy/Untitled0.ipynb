# %%
# !cat ODEExercises.ipynb
# Out:
# {
#  "metadata": {
#   "name": "",
#   "signature": "sha256:828a71e1cc75a17dfacf340f45d13094a6babc4897651331ef8802b4d87ea2aa"
#  },
#  "nbformat": 3,
#  "nbformat_minor": 0,
#  "worksheets": [
#   {
#    "cells": [
#     {
#      "cell_type": "heading",
#      "level": 1,
#      "metadata": {},
#      "source": [
#       "ODE Exercises"
#      ]
#     },
#     {
#      "cell_type": "heading",
#      "level": 2,
#      "metadata": {},
#      "source": [
#       "Question 1"
#      ]
#     },
#     {
#      "cell_type": "code",
#      "collapsed": false,
#      "input": [
#       "%pylab inline\n",
#       "import numpy as np\n",
#       "import matplotlib.pyplot as plt\n",
#       "from scipy.integrate import odeint"
#      ],
#      "language": "python",
#      "metadata": {},
#      "outputs": [
#       {
#        "output_type": "stream",
#        "stream": "stdout",
#        "text": [
#         "Populating the interactive namespace from numpy and matplotlib\n"
#        ]
#       }
# ...

# %%
# %%file ODEExercises.ipynb
# Out:
# UsageError: %%file is a cell magic, but the cell body is empty.
