# %% [markdown]
# # Random Numbers, Monte Carlo Sampling and Simulation Exercises

# %% [markdown]
# ## Question 2

# %% [markdown]
# The Weibull distribution, with parameters α>0 and β>0 is described by the density function
#
# f(x)={αβ−αxα−1e−(x/β)α0x>0otherwise
#
# (a) Solve for the CDF of the Weibull distribution analytically, using
#
# F(x)=∫x−∞f(t)dt

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plot
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['plot', 'interactive']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
from IPython.html.widgets import interact, interactive
from scipy.integrate import trapz,cumtrapz

# %%
def CDFviewer(xmax = 0.95):

    a = 1
    b = 1
    x = np.arange(0.,20,0.1)
    func = lambda x: a*(b**(-a))*(x**(a-1))*exp(-(x/b)**a)
        
    #Plot the full function first
    plt.plot(x,func(x),label='True distribution',lw=3)

    #Now show the CDF up to the xmax limit
    xcdf = np.arange(0.,xmax+0.01,0.01)
    Func = trapz(func(xcdf),xcdf)
    plt.plot(xcdf,Func,label='Cumulative function',lw=3)

    plt.plot((xmax,xmax),(0.,func(xmax)),"b--")
    plt.fill_between(xcdf,0.,func(xcdf),alpha=0.1)
    
    #Use trapz with the true distribution as a comparison, but only integrate
    #up to xmax
    total = trapz(func(x),x)
    area = trapz(func(xcdf),xcdf)
    frac = area/total
    
    plt.text(2.0,0.6,"CDF value = %.3f"%F(xmax),fontsize=12)
    plt.text(2.0,0.5,"Shaded area = %.3f"%frac,fontsize=12)
    
    plt.xlim(0,3.5)
    plt.ylim(0,1.1)

    plt.legend(loc="upper left")
    plt.show()


v = interact(CDFviewer,xmax=(0.,np.pi,0.01))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-abef4af35eb4> in CDFviewer(xmax)
#      12     xcdf = np.arange(0.,xmax+0.01,0.01)
#      13     Func = trapz(func(xcdf),xcdf)
# ---> 14     plt.plot(xcdf,Func,label='Cumulative function',lw=3)
#      15
#      16     plt.plot((xmax,xmax),(0.,func(xmax)),"b--")
#
# C:\Users\SVPF\Anaconda\lib\site-packages\matplotlib\pyplot.pyc in plot(*args, **kwargs)
#    2985         ax.hold(hold)
#    2986     try:
# -> 2987         ret = ax.plot(*args, **kwargs)
#    2988         draw_if_interactive()
#    2989     finally:
#
# C:\Users\SVPF\Anaconda\lib\site-packages\matplotlib\axes.pyc in plot(self, *args, **kwargs)
#    4135         lines = []
#    4136
# -> 4137         for line in self._get_lines(*args, **kwargs):
#    4138             self.add_line(line)
#    4139             lines.append(line)
#
# ...

# %% [markdown]
# (b) Find the inverse of the CDF F−1(x) analytically.

# %%
# Out:
# Random number =  0.568833432844
# x location =  0.832
